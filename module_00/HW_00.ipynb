# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# # HW_00 - Generative AI writing analysis
#
# In this assignment, you will generate instructions on brushing your teeth. You can use [ChatGPT](https://chatgpt.com/)
#
# Some metrics to add to the generated instructions:
#
# - number of strokes per minute
# - total brushing time
# - time spent per tooth
# - number of teeth or total area to brush on teeth
# - deflection of brush bristles for proper cleaning
# - what else can you think of?

# %% [markdown]
# ## Prompt Input and Output
#
#
# Input: Give me a detailed yet concise explanation of how to brush your teeth. Give metrics such as the number of strokes per minute , total brushing time, time spent per tooth, number of teeth or total area to brush on teeth, as well as which teeth to focus on at which time within the brushing cycle.
#
#
# Output:Brushing your teeth effectively involves a precise technique to ensure you clean all areas of your mouth thoroughly. Here's a detailed, step-by-step guide with metrics:
#
# 1. Brushing Time & Frequency
# Total Time: Brush for at least 2 minutes.
# Frequency: Brush twice a day—morning and night.
# 2. Toothbrush Motion & Strokes
# Strokes per Minute: Aim for around 300 strokes per minute.
# Strokes per Tooth: Roughly 5-10 strokes per tooth depending on size and angle.
# 3. Brushing Technique
# Use a gentle circular or elliptical motion to avoid damaging gums and enamel.
# Angle the brush at a 45-degree angle towards your gumline to effectively remove plaque.
# 4. Brushing Areas & Tooth Focus
# Upper Teeth (Front): Start with the upper front teeth, brushing in small circular motions. Focus on both the inside and outside surfaces. Spend about 10-15 seconds per quadrant (i.e., top left, top right).
# Upper Teeth (Back): For the back upper teeth, use short strokes along the outside and inside surfaces. Angle the brush at 45 degrees to the gums. Focus on the molars as they tend to gather more plaque.
# Lower Teeth (Front): Move to the lower front teeth, brushing in the same gentle circular motion.
# Lower Teeth (Back): For the lower back teeth, follow the same procedure, paying special attention to the back molars and inside areas.
# 5. Dividing the Mouth
# Divide the mouth into 4 quadrants: Upper left, upper right, lower left, lower right.
# Brush each quadrant for 30 seconds to ensure thorough cleaning.
# 6. Areas of Focus
# Spend a bit more time focusing on:
# Gumline (where plaque can accumulate).
# Molars and hard-to-reach areas like the back of the mouth.
# Chewing surfaces: Brush the top of the molars with a gentle back-and-forth motion.
# Areas where you may have experienced dental problems in the past.
# 7. Flossing
# After brushing, it’s recommended to floss to remove debris between the teeth and along the gumline.
# 8. Rinsing
# Optionally, rinse with mouthwash after brushing to kill bacteria and freshen breath.
# Summary:
# 2 minutes total (30 seconds per quadrant).
# 300 strokes per minute (gentle circular or elliptical motion).
# Focus on gumline, molars, and back teeth.
# Brush all surfaces of each tooth: outside, inside, and chewing surfaces.
# By maintaining this thorough approach, you can effectively clean your teeth and gums, helping to prevent cavities and gum disease.

# %% [markdown]
# ## Revised document
#
# Input: Give me a detailed yet concise explanation of how to brush your teeth. Give metrics such as the number of strokes per minute , total brushing time, time spent per tooth, number of teeth or total area to brush on teeth, as well as which teeth to focus on at which time within the brushing cycle.
#
#
# Output:Brushing your teeth effectively involves a precise technique to ensure you clean all areas of your mouth thoroughly. Here's a detailed, step-by-step guide with metrics:
#
# 1. Brushing Time & Frequency
# Total Time: Brush for at least 2 minutes.
# Frequency: Brush twice a day at morning and at night.
# 2. Toothbrush Motion & Strokes
# Strokes per Minute: Brush around 300 strokes per minute.
# Strokes per Tooth: Roughly 5-10 strokes per tooth depending on size and angle.
# 3. Brushing Technique
# Use a gentle circular or elliptical motion to avoid damaging gums and enamel.
# Angle the brush at a 45-degree angle towards your gumline to remove plaque as that is where most of the plaque builds up.
# 4. Brushing Areas & Tooth Focus
# Upper Teeth (Front): Start with the upper front teeth, brushing in small circular motions. Focus on both the inside and outside surfaces. Spend about 10-15 seconds per area.
# Upper Teeth (Back): For the back upper teeth, use short strokes along the outside and inside surfaces. Angle the brush at 45 degrees to the gums. Focus on the molars as they usually gather more plaque.
# Lower Teeth (Front): Move to the lower front teeth, brushing in the same gentle circular motion.
# Lower Teeth (Back): For the lower back teeth, follow the same procedure, paying special attention to the back molars and inside areas.
# 5. Dividing the Mouth
# Divide the mouth into different areas of focus.
# Brush each area for 30 seconds to ensure thorough cleaning.
# 6. Areas of Focus
# Spend more time focusing on your gumline, Molars and hard-to-reach areas like the back of the mouth, Chewing surfaces: Brush the top of the molars with a gentle back-and-forth motion.
# 7. Flossing
# After brushing, you should floss to remove debris between the teeth and along the gumline.
# 8. Rinsing
# To kill bacteria and freshen breath you should rinse with mouthwash after brushing .
# 9. Dental Check-ups
# Although this is not regarding brushing teeth, going to a dentist 2x per year to keep up with teeth cleanings and check ups can keep your teeth healthy and ensure you don't have any problems in the future.
# Summary:
# 2 minutes total (30 seconds per grouped area).
# 300 strokes per minute (gentle circular or elliptical motion).
# Focus on gumline, molars, and back teeth.
# Brush all surfaces of each tooth: outside, inside, and chewing surfaces.
# By maintaining this thorough approach, you can effectively clean your teeth and gums, helping to prevent cavities and gum disease.

# %% [markdown]
# ## Document analysis
#
# - Make a list of all the improvements and changes you made to document
#
# Changed:
#  - Says at morning and at night instead of -morning and night
#  - Instead of "aim for" a certian amount of strokes I said to "brush"
#  - When mentioning the angle that effectively removes plaque I said it removes plaque since that is where most tends to build up
#  - Changed the wording from "quadrant" to "area" when refering to the area of teeth
#  -  Changed "tend to" to "usually"
#  - Took out "a bit" more time to be more concise
#  - Instead of "It is recommended" I said "You should"
#  - Changing how to divide mouth in different areas
#  - Changed wording on rinsing section
#  - Added section 9
#
#
# - use the `tf_idf.cosineSimilarity` function to compare the AI version to your own
#
# Write a report on your intellectual property  in the 'revised document'.
# - How much can you claim as yours?
# - How many ideas came from AI?
# - How many ideas came from you?
# - Is this a _new_ document?
# - If this work was made by you and another person-not AI-would you need to credit this person as a coauthor?
# - What else can you discuss about this comparison and this process?
#
# I would say a very minimal amount would be able to be claimed as mine as all the ideas came from AI and I just changed some of the langauge of the ideas given to me. All the answers came from Ai and I just edited some of the thoughts and wordings. Technically the ideas all came from me as I gave AI the prompt but all the responses were not my own. I would not consider this a new document as it is just paraphrased a very minuscule amount. Yes, the other person would need to be credited like how you would credit someone for quotes or paraphrased ideas though in this case you are doing it for the majority of the concepts so yes they would be a co-author at the very least. I can say that I could have gotten the texts to be much more different had I given AI a shorter prompt and added more of my own ideas from my own research rather than having it look into all the thoughts about brushing teeth at once.
#
# _run the cell below to get your `tf_idf` functions ready to run_

# %%
! pip install tf-idf-cosimm==0.0.2

# %%
import tf_idf.core as tf_idf

# %%
AI = '''Brushing your teeth effectively involves a precise technique to ensure you clean all areas of your mouth thoroughly. Here's a detailed, step-by-step guide with metrics:

1. Brushing Time & Frequency
Total Time: Brush for at least 2 minutes.
Frequency: Brush twice a day—morning and night.
2. Toothbrush Motion & Strokes
Strokes per Minute: Aim for around 300 strokes per minute.
Strokes per Tooth: Roughly 5-10 strokes per tooth depending on size and angle.
3. Brushing Technique
Use a gentle circular or elliptical motion to avoid damaging gums and enamel.
Angle the brush at a 45-degree angle towards your gumline to effectively remove plaque.
4. Brushing Areas & Tooth Focus
Upper Teeth (Front): Start with the upper front teeth, brushing in small circular motions. Focus on both the inside and outside surfaces. Spend about 10-15 seconds per quadrant (i.e., top left, top right).
Upper Teeth (Back): For the back upper teeth, use short strokes along the outside and inside surfaces. Angle the brush at 45 degrees to the gums. Focus on the molars as they tend to gather more plaque.
Lower Teeth (Front): Move to the lower front teeth, brushing in the same gentle circular motion.
Lower Teeth (Back): For the lower back teeth, follow the same procedure, paying special attention to the back molars and inside areas.
5. Dividing the Mouth
Divide the mouth into 4 quadrants: Upper left, upper right, lower left, lower right.
Brush each quadrant for 30 seconds to ensure thorough cleaning.
6. Areas of Focus
Spend a bit more time focusing on:
Gumline (where plaque can accumulate).
Molars and hard-to-reach areas like the back of the mouth.
Chewing surfaces: Brush the top of the molars with a gentle back-and-forth motion.
7. Flossing
After brushing, it’s recommended to floss to remove debris between the teeth and along the gumline.
8. Rinsing
Optionally, rinse with mouthwash after brushing to kill bacteria and freshen breath.
Summary:
2 minutes total (30 seconds per quadrant).
300 strokes per minute (gentle circular or elliptical motion).
Focus on gumline, molars, and back teeth.
Brush all surfaces of each tooth: outside, inside, and chewing surfaces.
By maintaining this thorough approach, you can effectively clean your teeth and gums, helping to prevent cavities and gum disease.'''
compare = tf_idf.preprocess_text(AI)

# %%
ME = '''Brushing your teeth effectively involves a precise technique to ensure you clean all areas of your mouth thoroughly. Here's a detailed, step-by-step guide with metrics:

1. Brushing Time & Frequency
Total Time: Brush for at least 2 minutes.
Frequency: Brush twice a day at morning and at night.
2. Toothbrush Motion & Strokes
Strokes per Minute: Brush around 300 strokes per minute.
Strokes per Tooth: Roughly 5-10 strokes per tooth depending on size and angle.
3. Brushing Technique
Use a gentle circular or elliptical motion to avoid damaging gums and enamel.
Angle the brush at a 45-degree angle towards your gumline to remove plaque as that is where most of the plaque builds up.
4. Brushing Areas & Tooth Focus
Upper Teeth (Front): Start with the upper front teeth, brushing in small circular motions. Focus on both the inside and outside surfaces. Spend about 10-15 seconds per area.
Upper Teeth (Back): For the back upper teeth, use short strokes along the outside and inside surfaces. Angle the brush at 45 degrees to the gums. Focus on the molars as they usually gather more plaque.
Lower Teeth (Front): Move to the lower front teeth, brushing in the same gentle circular motion.
Lower Teeth (Back): For the lower back teeth, follow the same procedure, paying special attention to the back molars and inside areas.
5. Dividing the Mouth
Divide the mouth into different areas of focus.
Brush each area for 30 seconds to ensure thorough cleaning.
6. Areas of Focus
Spend more time focusing on your gumline, Molars and hard-to-reach areas like the back of the mouth, Chewing surfaces: Brush the top of the molars with a gentle back-and-forth motion.
7. Flossing
After brushing, you should floss to remove debris between the teeth and along the gumline.
8. Rinsing
To kill bacteria and freshen breath you should rinse with mouthwash after brushing .
9. Dental Check-ups
Although this is not regarding brushing teeth, going to a dentist 2x per year to keep up with teeth cleanings and check ups can keep your teeth healthy and ensure you don't have any problems in the future.
Summary:
2 minutes total (30 seconds per grouped area).
300 strokes per minute (gentle circular or elliptical motion).
Focus on gumline, molars, and back teeth.
Brush all surfaces of each tooth: outside, inside, and chewing surfaces.
By maintaining this thorough approach, you can effectively clean your teeth and gums, helping to prevent cavities and gum disease.'''
compare = pd.concat([compare, tf_idf.preprocess_text(ME)],
                    ignore_index=True)
compare
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
tf_idf.cosineSimilarity(compare)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
